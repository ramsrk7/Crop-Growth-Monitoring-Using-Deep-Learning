# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
image = np.load('image.npy')
label = pd.read_csv('label.csv')

# %%
data = pd.DataFrame()

# %%
data['image'] = image
data['label'] = label['1']

# %%
data.sample(3)
# Out:
#                                                  image  label
# 44   [[[255, 255, 255], [255, 255, 255], [255, 255,...    1.0
# 174  [[[115, 121, 15], [115, 121, 15], [116, 122, 1...    3.0
# 143  [[[254, 244, 255], [254, 244, 255], [254, 244,...    3.0

# %%
plt.imshow(data.image[44])
